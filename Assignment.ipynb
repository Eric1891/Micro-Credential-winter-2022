# %% [markdown]
# <a href="https://colab.research.google.com/github/Eric1891/Micro-Credential-winter-2022/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #In class Assignment
# ##Find  a sport database
# ##After conduction initial EDA which include and not limited to:
# ##    1. Change at least two column names and complete at least one broadcast operation.
# ##        (make sure to make a copy of the new version of the dataset once in a while)
# ##Answer questions:
# ##  1. Who are the highest paid playes in the sport.
# ##  2. who is the most efficient player in that sport
# ##  3. Which is the better team in that Sport
# ##  4.Come up with 5 more questions and answers

# %%
import numpy as np
import pandas as pd

# %%
mls = pd.read_csv('https://raw.githubusercontent.com/jlcalleu18/ML-Data/main/mls-salaries-2017.csv')

# %%
mls2 = mls.copy();

# %%
mls2.to_csv('/content/drive/MyDrive/Data Analytics Winter 2022/Week2/Data/mls2.csv')

# %%
mls2.head()
# Out:
#   club last_name first_name position  base_salary  guaranteed_compensation
# 0  ATL   Almiron     Miguel        M    1912500.0               2297000.00
# 1  ATL   Ambrose      Mikey        D      65625.0                 65625.00
# 2  ATL      Asad      Yamil        M     150000.0                150000.00
# 3  ATL     Bloom       Mark        D      99225.0                106573.89
# 4  ATL  Carleton     Andrew        F      65000.0                 77400.00

# %% [markdown]
# ##Change at least two column names

# %%
mls2.rename(columns={'club':'CLUB','last_name':'LAST_NAME'},inplace=True)

# %%
mls2
# Out:
#     CLUB LAST_NAME    first_name position  base_salary  guaranteed_compensation
# 0    ATL   Almiron        Miguel        M    1912500.0               2297000.00
# 1    ATL   Ambrose         Mikey        D      65625.0                 65625.00
# 2    ATL      Asad         Yamil        M     150000.0                150000.00
# 3    ATL     Bloom          Mark        D      99225.0                106573.89
# 4    ATL  Carleton        Andrew        F      65000.0                 77400.00
# ..   ...       ...           ...      ...          ...                      ...
# 611  VAN  Tornaghi         Paolo       GK      80000.0                 80000.00
# 612  VAN    Waston       Kendall        D     350000.0                368125.00
# 613  VAN  Williams       Sheanon        D     175000.0                184000.00
# 614  NaN   Babouli            Mo        F      54075.0                 54075.00
# 615  NaN    Ramajo  David Mateos        D     420000.0                453333.33
#
# ...

# %% [markdown]
# ##broadcast operation

# %%
mls2['base_salary'].div(1000000)
# Out:
# 0      1.912500
# 1      0.065625
# 2      0.150000
# 3      0.099225
# 4      0.065000
#          ...
# 611    0.080000
# 612    0.350000
# 613    0.175000
# 614    0.054075
# 615    0.420000
# Name: base_salary, Length: 616, dtype: float64

# %% [markdown]
# ##Who are the highest paid playes in the sport.

# %%
mls2[mls.base_salary == mls.base_salary.max()]
# Out:
#     club last_name first_name position  base_salary  guaranteed_compensation
# 401  ORL      Kaka        NaN        M    6660000.0                7167500.0

# %%
mls2.nlargest(2,'base_salary')
# Out:
#     club last_name first_name position  base_salary  guaranteed_compensation
# 401  ORL      Kaka        NaN        M    6660000.0                7167500.0
# 560  TOR   Bradley    Michael        M    6000000.0                6500000.0

# %% [markdown]
# ##who is the most efficient player in that sport

# %%
mlsSoccer = pd.read_csv('https://raw.githubusercontent.com/mesbasajib/soccer_data/main/all_goalkeepers.csv')

# %%
mlsSoccer
# Out:
#                 Player Club POS  GP  GS  MINS  ...  T  ShO    W%   Sv%  Year  Season
# 0            Mark Dodd  DAL  GK  31  31  2776  ...  0    6  54.8  68.1  1996     reg
# 1           Tony Meola  MET  GK  29  29  2610  ...  0    9  48.3  75.5  1996     reg
# 2       Mark Dougherty  TB   GK  28  28  2520  ...  0    3  60.7  66.1  1996     reg
# 3         Jorge Campos  LA   GK  24  24  2160  ...  0    4  54.2  75.2  1996     reg
# 4       Garth Lagerwey  KC   GK  23  22  1959  ...  0    3  52.2  62.4  1996     reg
# ...                ...  ...  ..  ..  ..   ...  ... ..  ...   ...   ...   ...     ...
# 2001   Adrian Zendejas  NaN  GK   0   0     0  ...  0    0   0.0   0.0  2020    post
# 2002   Mason Stajduhar  NaN  GK   0   0     0  ...  0    0   0.0   0.0  2020    post
# 2003       Brady Scott  NaN  GK   0   0     0  ...  0    0   0.0   0.0  2020    post
# 2004  Kendall McIntosh  NaN  GK   0   0     0  ...  0    0   0.0   0.0  2020    post
# ...

# %%
player = mlsSoccer.nlargest(10,'MINS')

# %%
player.nlargest(1, 'GA')
# Out:
#         Player Club POS  GP  GS  MINS  ...   T  ShO    W%   Sv%  Year  Season
# 800  Jon Busch  SJ   GK  34  34  3060  ...  12    6  17.6  71.7  2014     reg
#
# [1 rows x 19 columns]

# %% [markdown]
# ##Which is the better team in that Sport

# %%
team = mlsSoccer.nlargest(3,'W')
team[['Club', 'W', 'W%']]
# Out:
#      Club   W    W%
# 73    LA   22  75.9
# 48    KC   21  72.4
# 1080  MIA  21  67.7

# %% [markdown]
# ##Come up with 5 more questions and answers

# %%
#Team that lost the most games
lost = mlsSoccer.nsmallest(3, 'L')
lost[['Club','W','L','W%','Year']]
# Out:
#    Club  W  L     W%  Year
# 22  DC   0  0    0.0  1996
# 45  DC   0  0    0.0  1996
# 67  DAL  2  0  100.0  1997

# %%
#The top goal scorer of the season
player.nlargest(1, 'GA')
# Out:
#         Player Club POS  GP  GS  MINS  ...   T  ShO    W%   Sv%  Year  Season
# 800  Jon Busch  SJ   GK  34  34  3060  ...  12    6  17.6  71.7  2014     reg
#
# [1 rows x 19 columns]
