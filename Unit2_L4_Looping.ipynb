# %% [markdown]
# <a href="https://colab.research.google.com/github/Eric1891/Micro-Credential-winter-2022/blob/main/Unit2_L4_Looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lesson 4 – Looping

# %% [markdown]
# #Create a list that holds 5 data variables.

# %%
x = [2,4,5,7,9]

# %%
x
# Out:
# [2, 4, 5, 7, 9]

# %% [markdown]
# #Print out those variables by using a for loop.

# %%
for i in x:
  print(i)
# Out:
# 2
# 4
# 5
# 7
# 9

# %% [markdown]
# #Modify your for loop to add a message to your for loop.

# %%
for i in x:
  if i % 2 == 0:
    print(i)
  else:
    print(i, 'This is not an even number')
# Out:
# 2
# 4
# 5 This is not an even number
# 7 This is not an even number
# 9 This is not an even number

# %% [markdown]
# #Use a for loop to print even numbers from 1-20.

# %%
for x in range (1,20):
  if x % 2 == 0:
    print(x)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %% [markdown]
# #Sort your list in alphabetic order.

# %%
guests = ['James', 'Mary', 'John', 'Patricia', 'Robert', 'Jennifer']
guests.sort()

print(guests)
# Out:
# ['James', 'Jennifer', 'John', 'Mary', 'Patricia', 'Robert']

# %% [markdown]
# # Print out the first three elements of your list.

# %%
guests[:3]
# Out:
# ['James', 'Jennifer', 'John']

# %% [markdown]
# #Create a loop to print the last 2 elements of your list.

# %%
guests[-3:]
# Out:
# ['Mary', 'Patricia', 'Robert']
